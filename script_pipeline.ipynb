# %% [markdown]
# # Script pipeline

# %% [markdown]
# ## Before starting
#
# Collect your videos in MP4 format, give them a unique commercial ID (make sure their names are the same of the corresponding `commerical_id` values) and put them in the `videos` folder.
#
# Then fill in the CSV file `initial_data/commercials_initial_metadata.csv` with the metadata of each video:
#
# - `commercial_id`
# - `title`
# - `brand`
# - `nice_class`
# - `product_type_key`
# - `year`
# - `lustrum`
# - `source`

# %% [markdown]
# ## 1. Color and Thumb Extraction
#
# - Analyze each video and collects new data (`avg_frame_rate`, `aspect_ratio`), add them to `commercials_initial_metadata.csv` and save it as `general/commercials.csv`.
# - Split each video in “scenes”.
# - For each scene, extract the representative median frame and save it in small size (with height of 180 px), in WEBP format, in a folder named after the `commercial_id` in the `thumbnails` folder.
# - From each median frame, extract a color palette of maximum 32 colours and save them in a CSV file named
#   `general/commercial_palettes.csv` with these data:
#     - `commercial_id`
#     - `scene`: the progressive number ID of the scene.
#     - `scene_size`: the scene duration measured in frames.
#     - `start_frame`: the initial frame number of the scene.
#     - `end_frame`: the final frame number of the scene.
#     - `hex_code`: the hexadecimal representation of the original colour extracted.
#     - `frequency_within_the_scene`: the frequency of the original colour in the scene.
#     - `closest_color_ext_pal`: the closet colour from the extended palette.
#     - `closest_color_ess_pal`: the closet colour from the essential palette.
#     - `closest_color_bas_pal`: the closet colour from the basic palette.
#     - `scene_size_norm`: the normalized scene size.
#     - `frequency_within_the_commercial`: the frequency of the original colour within the video (`frequency_within_the_scene` × `scene_size_norm`)
#     - `tf`: the term frequency of the `closest_color_ext_pal` value in the video.
# - save the info about each scene detected in each video into `general/scenes.csv`.

# %%
# %run '1_color_and_thumb_extraction.py'
# Out:
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 1. Parse the videos
# ➡️ Get video info, split the video in scenes, save screenshots,
# ➡️ extract colors and save them in a .pal.csv file.
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ------------------------------------------------
# 📼 Video 1/4: 7cf5ef492fe149249fb0743058b4b7a9_030
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329e78000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329ec8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x3281d0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x3281d0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x329c50000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x3281d0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x160428000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x1200d0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x127ff0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x1200d0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x127ff0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x1200d0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x127ff0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x1200d0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x127ff0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0
] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x150078000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x150160000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x160428000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x160448000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x160428000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x160448000] No accelerated colorspace conversion found from yuv420p to bgr24.
# INFO:pyscenedetect:Detecting scenes...
# INFO:pyscenedetect:Splitting video with ffmpeg, output path template:
#   $VIDEO_NAME.ss$SCENE_NUMBER.mp4
# INFO:pyscenedetect:Output folder:
#   $VIDEO_NAME.ss$SCENE_NUMBER.mp4
# INFO:pyscenedetect:Saving 1 images per scene [format=png] screenshots/qI6VEpzHQ-M
# [swscaler @ 0x127ff0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x4732b8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x126438000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x3203c8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x145880000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x126420000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [swscaler @ 0x160428000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 🎨 Saved `commercial_palettes/qI6VEpzHQ-M.pal.csv`
# ------------------------------------------------
# 📄 Updated `general/commercials.csv`
#
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 2. Enrich the .pal.csv file with reference colors
# ➡️ Assign the closest reference palette colors to each color extracted,
# ➡️ remove the first and/or the last scene if `black` (from essential palette) is the predominant color,
# ➡️ add for each color the frequency within the scene,
# ➡️ update the .pal.csv file.
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ------------------------------------------------
# 📼 Video 1/4: 7cf5ef492fe149249fb0743058b4b7a9_030
# 🎨 Updated `commercial_palettes/7cf5ef492fe149249fb0743058b4b7a9_030.pal.csv`
# ------------------------------------------------
# 📼 Video 2/4: 732dc471d65b4b14bd64321c1a537c88_030
# 🎨 Updated `commercial_palettes/732dc471d65b4b14bd64321c1a537c88_030.pal.csv`
# ------------------------------------------------
# 📼 Video 3/4: gSnVME7YCVQ
# 🎨 Updated `commercial_palettes/gSnVME7YCVQ.pal.csv`
# ------------------------------------------------
# 📼 Video 4/4: qI6VEpzHQ-M
# 🎨 Updated `commercial_palettes/qI6VEpzHQ-M.pal.csv`
#
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 3. Create scenes.csv
# ➡️ Create a new dataset just for the scenes of each video with their
# ➡️ scene sizes, start frames, end frames, scene sizes normalized and scene duration in seconds
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ------------------------------------------------
# 📼 Video 1/4: 7cf5ef492fe149249fb0743058b4b7a9_030
# ------------------------------------------------
# 📄 Updated `general/commercials.csv`
# ------------------------------------------------
# 📼 Video 2/4: 732dc471d65b4b14bd64321c1a537c88_030
# ------------------------------------------------
# 📄 Updated `general/commercials.csv`
# ------------------------------------------------
# 📼 Video 3/4: gSnVME7YCVQ
# ------------------------------------------------
# 📄 Updated `general/commercials.csv`
# ------------------------------------------------
# 📼 Video 4/4: qI6VEpzHQ-M
# ------------------------------------------------
# 📄 Updated `general/commercials.csv`
# ------------------------------------------------
# 📄 `general/scenes.csv` has been updated
#
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 4. Generate scene thumbnails
# ➡️ Convert the PNG screenshots to low resolution WEBP thumbnails (in the folder `thumbnails`),
# ➡️ delete PNG screenshots and `screenshots` folder.
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🖼️ Scene 2/7: `qI6VEpzHQ-M.ss002.png` => `qI6VEpzHQ-M.ss002.webp`
# 🖼️ Scene 3/7: `qI6VEpzHQ-M.ss003.png` => `qI6VEpzHQ-M.ss003.webp`
# 🖼️ Scene 4/7: `qI6VEpzHQ-M.ss004.png` => `qI6VEpzHQ-M.ss004.webp`
# 🖼️ Scene 5/7: `qI6VEpzHQ-M.ss005.png` => `qI6VEpzHQ-M.ss005.webp`
# 🖼️ Scene 6/7: `qI6VEpzHQ-M.ss006.png` => `qI6VEpzHQ-M.ss006.webp`
# 🖼️ Scene 7/7: `qI6VEpzHQ-M.ss007.png` => `qI6VEpzHQ-M.ss007.webp`
# 🗑️ Deleted `screenshots/qI6VEpzHQ-M` folder
# ------------------------------------------------
# 🗑️ Deleted `screenshots` folder
#
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 5. Enrich the .pal.csv file with the term frequency of each color in each palette
# ➡️ Calculate the tf and update the .pal.csv file.
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ------------------------------------------------
# 📼 Video 1/4: 7cf5ef492fe149249fb0743058b4b7a9_030
# 🎨 Updated `commercial_palettes/7cf5ef492fe149249fb0743058b4b7a9_030.pal.csv`
# ------------------------------------------------
# 📼 Video 2/4: 732dc471d65b4b14bd64321c1a537c88_030
# 🎨 Updated `commercial_palettes/732dc471d65b4b14bd64321c1a537c88_030.pal.csv`
# ------------------------------------------------
# 📼 Video 3/4: gSnVME7YCVQ
# 🎨 Updated `commercial_palettes/gSnVME7YCVQ.pal.csv`
# ------------------------------------------------
# 📼 Video 4/4: qI6VEpzHQ-M
# 🎨 Updated `commercial_palettes/qI6VEpzHQ-M.pal.csv`
#
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 6. Concatenate all commercial palettes in a unique CSV file
# ➡️ Create the file commercial_palettes.csv file,
# ➡️ delete the commercial_palettes folder.
# ------------------------------------------------
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# 📼 Video 1/4: 7cf5ef492fe149249fb0743058b4b7a9_030
# 📼 Video 2/4: 732dc471d65b4b14bd64321c1a537c88_030
# 📼 Video 3/4: gSnVME7YCVQ
# 📼 Video 4/4: qI6VEpzHQ-M
# ------------------------------------------------
# 🎨 Saved `colors/commercial_palettes.csv`
# ------------------------------------------------
# 🗑️ Deleted `commercial_palettes` folder

# %% [markdown]
# ## 2. Reference Palette Idf Calculation
#
# Calculate the idfs (Inverse Document Frequencies) of each color for each reference palette and save them as:
# - `colors/basic_palette_idfs.csv`
# - `colors/essential_palette_idfs.csv`
# - `colors/extended_palette_idfs.csv`

# %%
# %run '2_ref_palette_idf_calculation.py'
# Out:
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 Calculate the idfs (Inverse Document Frequencies) of each color for each reference palette
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ➡️ Calculate the idfs,
# ➡️ save them in a CSV file (one for each reference palette).
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ------------------------------------------------
# 📄 Saved `colors/basic_palette_idfs.csv`
# ------------------------------------------------
# 📄 Saved `colors/essential_palette_idfs.csv`
# ------------------------------------------------
# 📄 Saved `colors/extended_palette_idfs.csv`

# %% [markdown]
# ## 3. Audio Feature Extraction
#
# Export the 19 audio features of each video in the folder `audio/features`.

# %%
# %run '3_audio_feature_extraction.py'
# Out:
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 Export the 19 audio features of each video
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ------------------------------------------------
# 📼 Video 1/4: qI6VEpzHQ-M
# /Users/dfadda/Git/tv-commercials-dataset/3_audio_feature_extraction.py:35: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=None)  # Load audio
# /opt/homebrew/anaconda3/envs/tv-demo/lib/python3.11/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# /opt/homebrew/anaconda3/envs/tv-demo/lib/python3.11/site-packages/tempocnn/feature.py:45: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file, sr=11025)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 🎶 Saved `audio/features/chroma_stft_files/7cf5ef492fe149249fb0743058b4b7a9_030.chroma_stft.npz`
# 🎶 Saved `audio/features/chroma_cqt_files/7cf5ef492fe149249fb0743058b4b7a9_030.chroma_cqt.npz`
# 🎶 Saved `audio/features/chroma_cens_files/7cf5ef492fe149249fb0743058b4b7a9_030.chroma_cens.npz`
# 🎶 Saved `audio/features/melspectrogram_files/7cf5ef492fe149249fb0743058b4b7a9_030.melspectrogram.npz`
# 🎶 Saved `audio/features/mfcc_files/7cf5ef492fe149249fb0743058b4b7a9_030.mfcc.npz`
# 🎶 Saved `audio/features/rms_files/7cf5ef492fe149249fb0743058b4b7a9_030.rms.npz`
# 🎶 Saved `audio/features/spectral_centroid_files/7cf5ef492fe149249fb0743058b4b7a9_030.spectral_centroid.npz`
# 🎶 Saved `audio/features/spectral_bandwidth_files/7cf5ef492fe149249fb0743058b4b7a9_030.spectral_bandwidth.npz`
# 🎶 Saved `audio/features/spectral_contrast_files/7cf5ef492fe149249fb0743058b4b7a9_030.spectral_contrast.npz`
# 🎶 Saved `audio/features/spectral_flatness_files/7cf5ef492fe149249fb0743058b4b7a9_030.spectral_flatness.npz`
# 🎶 Saved `audio/features/spectral_rolloff_files/7cf5ef492fe149249fb0743058b4b7a9_030.spectral_rolloff.npz`
# 🎶 Saved `audio/features/poly_features_files/7cf5ef492fe149249fb0743058b4b7a9_030.poly_features.npz`
# 🎶 Saved `audio/features/tonnetz_files/7cf5ef492fe149249fb0743058b4b7a9_030.tonnetz.npz`
# 🎶 Saved `audio/features/zero_crossing_rate_files/7cf5ef492fe149249fb0743058b4b7a9_030.zero_crossing_rate.npz`
# 🎶 Saved `audio/features/tempogram_files/7cf5ef492fe149249fb0743058b4b7a9_030.tempogram.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_default_prior_files/7cf5ef492fe149249fb0743058b4b7a9_030.librosa_static_tempo_default_prior.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_uniform_prior_files/7cf5ef492fe149249fb0743058b4b7a9_030.librosa_static_tempo_uniform_prior.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_lognorm_prior_files/7cf5ef492fe149249fb0743058b4b7a9_030.librosa_static_tempo_lognorm_prior.npz`
# 🎶 Saved `audio/features/tempocnn_static_tempo_files/7cf5ef492fe149249fb0743058b4b7a9_030.tempocnn_static_tempo.npz`
# ------------------------------------------------
# 📼 Video 2/4: qI6VEpzHQ-M
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 🎶 Saved `audio/features/chroma_stft_files/732dc471d65b4b14bd64321c1a537c88_030.chroma_stft.npz`
# 🎶 Saved `audio/features/chroma_cqt_files/732dc471d65b4b14bd64321c1a537c88_030.chroma_cqt.npz`
# 🎶 Saved `audio/features/chroma_cens_files/732dc471d65b4b14bd64321c1a537c88_030.chroma_cens.npz`
# 🎶 Saved `audio/features/melspectrogram_files/732dc471d65b4b14bd64321c1a537c88_030.melspectrogram.npz`
# 🎶 Saved `audio/features/mfcc_files/732dc471d65b4b14bd64321c1a537c88_030.mfcc.npz`
# 🎶 Saved `audio/features/rms_files/732dc471d65b4b14bd64321c1a537c88_030.rms.npz`
# 🎶 Saved `audio/features/spectral_centroid_files/732dc471d65b4b14bd64321c1a537c88_030.spectral_centroid.npz`
# 🎶 Saved `audio/features/spectral_bandwidth_files/732dc471d65b4b14bd64321c1a537c88_030.spectral_bandwidth.npz`
# 🎶 Saved `audio/features/spectral_contrast_files/732dc471d65b4b14bd64321c1a537c88_030.spectral_contrast.npz`
# 🎶 Saved `audio/features/spectral_flatness_files/732dc471d65b4b14bd64321c1a537c88_030.spectral_flatness.npz`
# 🎶 Saved `audio/features/spectral_rolloff_files/732dc471d65b4b14bd64321c1a537c88_030.spectral_rolloff.npz`
# 🎶 Saved `audio/features/poly_features_files/732dc471d65b4b14bd64321c1a537c88_030.poly_features.npz`
# 🎶 Saved `audio/features/tonnetz_files/732dc471d65b4b14bd64321c1a537c88_030.tonnetz.npz`
# 🎶 Saved `audio/features/zero_crossing_rate_files/732dc471d65b4b14bd64321c1a537c88_030.zero_crossing_rate.npz`
# 🎶 Saved `audio/features/tempogram_files/732dc471d65b4b14bd64321c1a537c88_030.tempogram.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_default_prior_files/732dc471d65b4b14bd64321c1a537c88_030.librosa_static_tempo_default_prior.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_uniform_prior_files/732dc471d65b4b14bd64321c1a537c88_030.librosa_static_tempo_uniform_prior.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_lognorm_prior_files/732dc471d65b4b14bd64321c1a537c88_030.librosa_static_tempo_lognorm_prior.npz`
# 🎶 Saved `audio/features/tempocnn_static_tempo_files/732dc471d65b4b14bd64321c1a537c88_030.tempocnn_static_tempo.npz`
# ------------------------------------------------
# 📼 Video 3/4: qI6VEpzHQ-M
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 🎶 Saved `audio/features/chroma_stft_files/gSnVME7YCVQ.chroma_stft.npz`
# 🎶 Saved `audio/features/chroma_cqt_files/gSnVME7YCVQ.chroma_cqt.npz`
# 🎶 Saved `audio/features/chroma_cens_files/gSnVME7YCVQ.chroma_cens.npz`
# 🎶 Saved `audio/features/melspectrogram_files/gSnVME7YCVQ.melspectrogram.npz`
# 🎶 Saved `audio/features/mfcc_files/gSnVME7YCVQ.mfcc.npz`
# 🎶 Saved `audio/features/rms_files/gSnVME7YCVQ.rms.npz`
# 🎶 Saved `audio/features/spectral_centroid_files/gSnVME7YCVQ.spectral_centroid.npz`
# 🎶 Saved `audio/features/spectral_bandwidth_files/gSnVME7YCVQ.spectral_bandwidth.npz`
# 🎶 Saved `audio/features/spectral_contrast_files/gSnVME7YCVQ.spectral_contrast.npz`
# 🎶 Saved `audio/features/spectral_flatness_files/gSnVME7YCVQ.spectral_flatness.npz`
# 🎶 Saved `audio/features/spectral_rolloff_files/gSnVME7YCVQ.spectral_rolloff.npz`
# 🎶 Saved `audio/features/poly_features_files/gSnVME7YCVQ.poly_features.npz`
# 🎶 Saved `audio/features/tonnetz_files/gSnVME7YCVQ.tonnetz.npz`
# 🎶 Saved `audio/features/zero_crossing_rate_files/gSnVME7YCVQ.zero_crossing_rate.npz`
# 🎶 Saved `audio/features/tempogram_files/gSnVME7YCVQ.tempogram.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_default_prior_files/gSnVME7YCVQ.librosa_static_tempo_default_prior.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_uniform_prior_files/gSnVME7YCVQ.librosa_static_tempo_uniform_prior.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_lognorm_prior_files/gSnVME7YCVQ.librosa_static_tempo_lognorm_prior.npz`
# 🎶 Saved `audio/features/tempocnn_static_tempo_files/gSnVME7YCVQ.tempocnn_static_tempo.npz`
# ------------------------------------------------
# 📼 Video 4/4: qI6VEpzHQ-M
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 🎶 Saved `audio/features/chroma_stft_files/qI6VEpzHQ-M.chroma_stft.npz`
# 🎶 Saved `audio/features/chroma_cqt_files/qI6VEpzHQ-M.chroma_cqt.npz`
# 🎶 Saved `audio/features/chroma_cens_files/qI6VEpzHQ-M.chroma_cens.npz`
# 🎶 Saved `audio/features/melspectrogram_files/qI6VEpzHQ-M.melspectrogram.npz`
# 🎶 Saved `audio/features/mfcc_files/qI6VEpzHQ-M.mfcc.npz`
# 🎶 Saved `audio/features/rms_files/qI6VEpzHQ-M.rms.npz`
# 🎶 Saved `audio/features/spectral_centroid_files/qI6VEpzHQ-M.spectral_centroid.npz`
# 🎶 Saved `audio/features/spectral_bandwidth_files/qI6VEpzHQ-M.spectral_bandwidth.npz`
# 🎶 Saved `audio/features/spectral_contrast_files/qI6VEpzHQ-M.spectral_contrast.npz`
# 🎶 Saved `audio/features/spectral_flatness_files/qI6VEpzHQ-M.spectral_flatness.npz`
# 🎶 Saved `audio/features/spectral_rolloff_files/qI6VEpzHQ-M.spectral_rolloff.npz`
# 🎶 Saved `audio/features/poly_features_files/qI6VEpzHQ-M.poly_features.npz`
# 🎶 Saved `audio/features/tonnetz_files/qI6VEpzHQ-M.tonnetz.npz`
# 🎶 Saved `audio/features/zero_crossing_rate_files/qI6VEpzHQ-M.zero_crossing_rate.npz`
# 🎶 Saved `audio/features/tempogram_files/qI6VEpzHQ-M.tempogram.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_default_prior_files/qI6VEpzHQ-M.librosa_static_tempo_default_prior.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_uniform_prior_files/qI6VEpzHQ-M.librosa_static_tempo_uniform_prior.npz`
# 🎶 Saved `audio/features/librosa_static_tempo_lognorm_prior_files/qI6VEpzHQ-M.librosa_static_tempo_lognorm_prior.npz`
# 🎶 Saved `audio/features/tempocnn_static_tempo_files/qI6VEpzHQ-M.tempocnn_static_tempo.npz`

# %% [markdown]
# ## 4. Audio Transcription and Lemmatization
#
# - Find the “Speech” presence in each video, save it as `audio/speech_class_confidence_score.csv` and transcribe the found speech. All transcriptions are saved in `text/transcriptions.csv`
# - Lemmatize each transcription and save lemmas (alphabetically ordered by video) as `text/lemmas.csv`.
# - Calculate the tf-idf values for each lemma and update `text/lemmas.csv`.

# %%
# %run '4_audio_transcription_and_lemmatization.py'
# Out:
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 1. Audio transcription
# ➡️ Find the “Speech” presence in each video,
# ➡️ transcribe the found speech.
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ------------------------------------------------
# 📂️ Create `tmp_wav` folder
# ------------------------------------------------
# 📂️ Create `text` folder
# ------------------------------------------------
# 📂️ Create `text/transcriptions` folder
# ------------------------------------------------
# ⏳️ Load YAMNet model from TensorFlow Hub (please wait…)
# ------------------------------------------------
# ⏳️ Initialize Whisper model (please wait…)
# ------------------------------------------------
# 📼 Video 1/4: 7cf5ef492fe149249fb0743058b4b7a9_030
# 📄 Exported `wav_file_path`
# 📝 Found 1 segment(s)
# [Segment 1] Ci sono persone che non possono permettersi di stare a casa anche quando fa brutto tempo. Hai primi sintomi di raffreddore o di influenza? Presto Aspirina. Aspirina. Va bene e presto. Seguire attentamente le avvertenze e le modalità d'uso.
# 📝 Saved `text/transcriptions/7cf5ef492fe149249fb0743058b4b7a9_030.transcription.csv`
# 🗑️ Deleted `tmp_wav/7cf5ef492fe149249fb0743058b4b7a9_030.wav`
# ------------------------------------------------
# 📼 Video 2/4: 732dc471d65b4b14bd64321c1a537c88_030
# 📄 Exported `wav_file_path`
# 📝 Found 2 segment(s)
# [Segment 1] Cebiopirina effervescente.
# [Segment 2] Cebiopirina Effervescente è un prodotto Bracco. Seguire attentamente le avvertenze e le modalità d'uso.
# 📝 Saved `text/transcriptions/732dc471d65b4b14bd64321c1a537c88_030.transcription.csv`
# 🗑️ Deleted `tmp_wav/732dc471d65b4b14bd64321c1a537c88_030.wav`
# ------------------------------------------------
# 📼 Video 3/4: gSnVME7YCVQ
# 📄 Exported `wav_file_path`
# 📝 Found 1 segment(s)
# [Segment 1] Che sapore ha un sogno che si avvera? Nuovo cono gelato Pan di Stelle. Mordi il biscotto, assapora la panna, scopri il cuore di cacao e nozzole. Gelato Pan di Stelle. Sogna, è buonissimo!
# 📝 Saved `text/transcriptions/gSnVME7YCVQ.transcription.csv`
# 🗑️ Deleted `tmp_wav/gSnVME7YCVQ.wav`
# ------------------------------------------------
# 📼 Video 4/4: qI6VEpzHQ-M
# 📄 Exported `wav_file_path`
# 📄 No transcription found (“Speech” score = 0)
# ------------------------------------------------
# 🗑️ Deleted `tmp_wav` folder
# ------------------------------------------------
# 🗑️ Deleted `text/transcriptions` folder
# ------------------------------------------------
# 📄 Saved `audio/speech_class_confidence_score.csv`
#
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 2. Lemmatization
# ➡️ Lemmatize each transcription,
# ➡️ save lemmas alphabetically ordered.
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ------------------------------------------------
# ⏳️ Download Stanza Italian model (please wait…)
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 434kB [00:00, 25.3MB/s]
# 2025-10-28 23:10:19 INFO: Downloaded file to /Users/dfadda/stanza_resources/resources.json
# INFO:stanza:Downloaded file to /Users/dfadda/stanza_resources/resources.json
# 2025-10-28 23:10:19 INFO: Downloading default packages for language: it (Italian) ...
# INFO:stanza:Downloading default packages for language: it (Italian) ...
# 2025-10-28 23:10:20 INFO: File exists: /Users/dfadda/stanza_resources/it/default.zip
# INFO:stanza:File exists: /Users/dfadda/stanza_resources/it/default.zip
# 2025-10-28 23:10:22 INFO: Finished downloading models and saved to /Users/dfadda/stanza_resources
# INFO:stanza:Finished downloading models and saved to /Users/dfadda/stanza_resources
# 2025-10-28 23:10:22 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ------------------------------------------------
# ⏳️ Load Italian NLP model (please wait…)
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 434kB [00:00, 23.7MB/s]
# 2025-10-28 23:10:22 INFO: Downloaded file to /Users/dfadda/stanza_resources/resources.json
# INFO:stanza:Downloaded file to /Users/dfadda/stanza_resources/resources.json
# 2025-10-28 23:10:22 INFO: Loading these models for language: it (Italian):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# | ner       | fbk               |
# =================================
#
# INFO:stanza:Loading these models for language: it (Italian):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# | ner       | fbk               |
# =================================
#
# 2025-10-28 23:10:22 INFO: Using device: cpu
# INFO:stanza:Using device: cpu
# 2025-10-28 23:10:22 INFO: Loading: tokenize
# INFO:stanza:Loading: tokenize
# 2025-10-28 23:10:22 INFO: Loading: mwt
# INFO:stanza:Loading: mwt
# 2025-10-28 23:10:22 INFO: Loading: pos
# INFO:stanza:Loading: pos
# 2025-10-28 23:10:23 INFO: Loading: lemma
# INFO:stanza:Loading: lemma
# 2025-10-28 23:10:24 INFO: Loading: depparse
# INFO:stanza:Loading: depparse
# 2025-10-28 23:10:24 INFO: Loading: ner
# INFO:stanza:Loading: ner
# 2025-10-28 23:10:25 INFO: Done loading processors!
# INFO:stanza:Done loading processors!
# ------------------------------------------------
# 📼 Video 1/4: 7cf5ef492fe149249fb0743058b4b7a9_030
# ------------------------------------------------
# 📼 Video 2/4: 732dc471d65b4b14bd64321c1a537c88_030
# ------------------------------------------------
# 📼 Video 3/4: gSnVME7YCVQ
#
# #*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*
# 🔵 3. Calculate the tf-idf values of each lemma
# ➡️ Calculate the tf-idf values,
# ➡️ update `lemmas.csv`.
# *#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
# ------------------------------------------------
# ⏳️ Download nltk  package `punkt` (please wait…)
# /Users/dfadda/Git/tv-commercials-dataset/4_audio_transcription_and_lemmatization.py:315: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ).apply(
# [nltk_data] Downloading package punkt to /Users/dfadda/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dfadda/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ------------------------------------------------
# ⏳️ Download nltk  package `stopwords` (please wait…)
# ------------------------------------------------
# ⚠️ Lemmas without tf-idf: {'anche', 'uno', 'il', 'non', 'di', 'e', 'a', 'che', 'ci', 'si', 'o'}
# ------------------------------------------------
# 📄 Updated `text/lemmas.csv`

# %% [markdown]
# ## Finally
#
# You can use `text/transcriptions.csv` as input for further text analysis (e.g. LIWC analysis).
